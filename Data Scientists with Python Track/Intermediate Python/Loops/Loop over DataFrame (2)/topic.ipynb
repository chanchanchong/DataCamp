# %% [markdown]
# ### Exercise
# # Loop over DataFrame (2)

# %% [markdown]
# The row data that's generated by `iterrows()` on every run is a Pandas Series. This format is not very convenient to print out. Luckily, you can easily select variables from the Pandas Series using square brackets:

# %%
for lab, row in brics.iterrows():
    print(row['country'])

# %% [markdown]
# ## Instructions
# * Using the iterators `lab` and `row`, adapt the code in the for loop such that the first iteration print outs "US: 809", the second iteration "AUS: 731", and so on.
# * The output should be in the form "country: cars_per_cap". Make sure to print out this exact string (with correct spacing).
#   * *You can use `str()` to convert your integer data to a string so that you can print it in conjunction with the country label*.

# %% [markdown]
# import cars data

# %%
import pandas as pd
cars = pd.read_csv('cars.csv', index_col=0)

# %% [markdown]
# Adapt for loop

# %%
for lab, row in cars.iterrows():
    print(f"{lab}: {row['cars_per_cap']}")
# Out:
# US: 809
# AUS: 731
# JAP: 588
# IN: 18
# RU: 200
# MOR: 70
# EG: 45

# %%
many_cars =  cpc > 500
many_cars
# Out:
# US      True
# AUS     True
# JAP     True
# IN     False
# RU     False
# MOR    False
# EG     False
# Name: cars_per_cap, dtype: bool

# %%
car_maniac = cars[many_cars]
car_maniac
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False

# %%
print(cars[cars['cars_per_cap'] > 500])
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
